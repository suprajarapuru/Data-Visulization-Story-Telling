# %% [markdown]
# #### DSC 640 - Data Visualization

# %%
## Import necessary packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
## Load data to data frame
df = pd.read_csv('C:/Users/Supraja/Desktop/Supraja WORK Apps/8. DSC640/Data/crimerates-by-state-2005.csv')

## Display data frame
df
# Out:
#                    state  murder  forcible_rape  robbery  aggravated_assault  \
# 0          United States     5.6           31.7    140.7               291.1
# 1                Alabama     8.2           34.3    141.4               247.8
# 2                 Alaska     4.8           81.1     80.9               465.1
# 3                Arizona     7.5           33.8    144.4               327.4
# 4               Arkansas     6.7           42.9     91.1               386.8
# 5             California     6.9           26.0    176.1               317.3
# 6               Colorado     3.7           43.4     84.6               264.7
# 7            Connecticut     2.9           20.0    113.0               138.6
# 8               Delaware     4.4           44.7    154.8               428.2
# 9   District of Columbia    35.4           30.2    672.1               721.3
# 10               Florida     5.0           37.1    169.4               496.6
# ...

# %%
## Show murder rate vs population
plt.rcParams["figure.figsize"] = (20,10)
plt.scatter(data=crime_df, x='robbery', y='population')
plt.title('Robbery Rate vs Population')
plt.xlabel('Robbery Rate')
plt.ylabel('Population')
plt.show()

# %%
## Show Robery rate vs population with burglary as the size
plt.rcParams["figure.figsize"] = (20,10)
plt.scatter(data=crime_df, x='robbery', y='population', s='burglary')
plt.title('Robbery and burglary vs Population')
plt.xlabel('Robbery Rate')
plt.ylabel('Population')
plt.show()

# %%
## Show density plot of murder rates
sn.kdeplot(crime_df['murder'], bw_method=0.25)
plt.title('Density Plot of Murder Rate')
plt.xlabel('Murder Rate')
plt.show()
